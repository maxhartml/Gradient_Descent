# %% [markdown]
# ### Neural Computation Week 2 Exercise: Gradient Descent for Linear Regression
#
# In this exercise, we'll develop implementations of gradient descent and its minibatch algorithms. As in Week 1 Exercise on linear regression, we will use the `Boston Housing` dataset. Instead of using the exact solution, which was explored in Week 1, here we use gradient descent and minibatch gradient descent to solve this problem.
#
# In this exercise, you will learn the following
# * implement the `gradient descent` method
# * implement the `minibatch gradient descent` method

# %%
import matplotlib
import numpy as np
import random
import warnings
import matplotlib.pyplot as plt
from sklearn import preprocessing   # for normalization

# %% [markdown]
# ## Boston Housing Data
#
# We will use the Boston Housing data, similar to Week 1. We can import the dataset and preprocess it as follows. Note we add a feature of $1$ to `x_input` to get a n x (d+1) matrix `x_in`

# %%
import pandas as pd
import numpy as np
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
boston_data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

data = boston_data
x_input = data  # a data matrix
y_target = target; # a vector for all outputs
# add a feature 1 to the dataset, then we do not need to consider the bias and weight separately
x_in = np.concatenate([np.ones([np.shape(x_input)[0], 1]), x_input], axis=1)
# we normalize the data so that each has regularity
x_in = preprocessing.normalize(x_in)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/mk/kkyfnpss5_3df7v6jr5_rr8h0000gn/T/ipykernel_34770/163381282.py:4: SyntaxWarning: invalid escape sequence '\s'
#   raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)

# %% [markdown]
# ## Linear Model
#
# A linear regression model in one variable has the following form
# $$
# f(x)=\mathbf{w}^\top \mathbf{x}.
# $$
# The following function computes the output of the linear model on a data matrix of size n x (d+1).

# %%
def linearmat_2(w, X):
    '''
    a vectorization of linearmat_1 in Week 1 lab.
    Input: w is a weight parameter (including the bias), and X is a data matrix (n x (d+1)) (including the feature)
    Output: a vector containing the predictions of linear models
    '''
    return np.dot(X, w)

# %% [markdown]
# ## Cost Function
#
# We defined the following `mean square error` function for a linear regression problem using the square loss:
# $$
# C(\mathbf{y}, \mathbf{t}) = \frac{1}{2n}(\mathbf{y}-\mathbf{t})^\top (\mathbf{y}-\mathbf{t}).
# $$
# The python implementation is as follows

# %%
def cost(w, X, y):
    '''
    Evaluate the cost function in a vectorized manner for
    inputs `X` and outputs `y`, at weights `w`.
    '''
    residual = y - linearmat_2(w, X)  # get the residual
    err = np.dot(residual, residual) / (2 * len(y)) # compute the error

    return err

# %% [markdown]
# ## Gradient Computation
#
# Our methods require to use the gradient of the `cost` function. As discussed in the lecture, the gradient can be computed by
# $$\nabla C(\mathbf{w}) =\frac{1}{n}X^\top\big(X\mathbf{w}-\mathbf{y}\big)$$
# In the following, we present the python implementation on the gradient computation

# %%
# Vectorized gradient function
def gradfn(weights, X, y):
    '''
    Given `weights` - a current "Guess" of what our weights should be
          `X` - matrix of shape (N,d+1) of input features including the feature $1$
          `y` - target y values
    Return gradient of each weight evaluated at the current value
    '''

    y_pred = np.dot(X, weights)
    error = y_pred - y
    return np.dot(X.T, error) / len(y)

# %% [markdown]
# ## Gradient Descent
#
# Gradient Descent iteratively updates the model by moving along the negative direction
# $$\mathbf{w}^{(t+1)} \leftarrow \mathbf{w}^{(t)} - \eta\nabla C(\mathbf{w}^{(t)}),$$
# where $\eta$ is a learning rate and $\nabla C(w^{(t)})$ is the gradient evaluated at current parameter value $\mathbf{w}^{(t)}$. In the following, we give the python implementation of the gradient descent on the linear regression problem. Here, we use `idx_res` to store the indices of iterations where we have computed the cost, and use `err_res` to store the cost of models at these iterations. These will be used to plot how the `cost` will behave `versus iteration` number.

# %%
def solve_via_gradient_descent(X, y, print_every=100,
                               niter=5000, eta=1):
    '''
    Given `X` - matrix of shape (N,D) of input features
          `y` - target y values
          `print_every` - we report performance every 'print_every' iterations
          `niter` - the number of iterates allowed
          `eta` - learning rate
    Solves for linear regression weights with gradient descent.

    Return
        `w` - weights after `niter` iterations
        `idx_res` - the indices of iterations where we compute the cost
        `err_res` - the cost at iterations indicated by idx_res
    '''
    N, D = np.shape(X)
    # initialize all the weights to zeros
    w = np.zeros([D])
    idx_res = []
    err_res = []
    for k in range(niter):
        # TODO: Insert your code to update w by gradient descent
        w = w - eta * gradfn(w, X, y)
        
        # we report the progress every print_every iterations
        if k % print_every == print_every - 1:
            t_cost = cost(w, X, y)
            print('error after %d iteration: %s' % (k, t_cost))
            idx_res.append(k)
            err_res.append(t_cost)
    return w, idx_res, err_res

# %% [markdown]
# Now we apply **gradient descent** to solve the **Boston House Price** prediction problem, and get the weight `w_gd`, the indices `idx_gd` and the errors 'err_gd' on these indices

# %%
w_gd, idx_gd, err_gd = solve_via_gradient_descent( X=x_in, y=y_target)
# Out:
# error after 99 iteration: 31.79169332623316
# error after 199 iteration: 31.023607992661898
# error after 299 iteration: 30.490383155279734
# error after 399 iteration: 30.089558295291933
# error after 499 iteration: 29.765768454560703
# error after 599 iteration: 29.488693376652886
# error after 699 iteration: 29.241419443720737
# error after 799 iteration: 29.014275853482015
# error after 899 iteration: 28.80155574427343
# error after 999 iteration: 28.599760789662742
# error after 1099 iteration: 28.406652720498368
# error after 1199 iteration: 28.220734140804865
# error after 1299 iteration: 28.040959208555275
# error after 1399 iteration: 27.866568543075
# error after 1499 iteration: 27.696992152320224
# error after 1599 iteration: 27.531790279455226
# error after 1699 iteration: 27.37061589773195
# error after 1799 iteration: 27.21318994176184
# error after 1899 iteration: 27.0592843049334
# error after 1999 iteration: 26.90870976389501
# error after 2099 iteration: 26.76130715867042
# error after 2199 iteration: 26.616940808457837
# error after 2299 iteration: 26.47549351550973
# error after 2399 iteration: 26.336862728845432
# error after 2499 iteration: 26.20095757351075
# error after 2599 iteration: 26.06769653622595
# error after 2699 iteration: 25.937005654602167
# error after 2799 iteration: 25.808817095850873
# error after 2899 iteration: 25.68306803846308
# error after 2999 iteration: 25.55969979047819
# error after 3099 iteration: 25.438657093001876
# error after 3199 iteration: 25.31988756904308
# error after 3299 iteration: 25.203341286496748
# error after 3399 iteration: 25.088970410870967
# error after 3499 iteration: 24.976728928624905
# error after 3599 iteration: 24.866572426097484
# error after 3699 iteration: 24.75845791222454
# error after 3799 iteration: 24.652343675767593
# error after 3899 iteration: 24.548189169757915
# error after 3999 iteration: 24.445954917416685
# error after 4099 iteration: 24.3456024350353
# error after 4199 iteration: 24.247094168262162
# error after 4299 iteration: 24.150393438998908
# error after 4399 iteration: 24.05546440070412
# error after 4499 iteration: 23.96227200037119
# error after 4599 iteration: 23.870781945814603
# error after 4699 iteration: 23.780960677190283
# error after 4799 iteration: 23.692775341901573
# error after 4899 iteration: 23.606193772224405
# error after 4999 iteration: 23.52118446512413

# %% [markdown]
# ## Minibatch Gradient Descent
#
# The optimization problem in ML often has a **sum** structure in the sense
# $$
# C(\mathbf{w})=\frac{1}{n}\sum_{i=1}^nC_i(\mathbf{w}),
# $$
# where $C_i(\mathbf{w})$ is the loss of the model $\mathbf{w}$ on the $i$-th example. In our Boston House Price prediction problem, $C_i$ takes the form $C_i(\mathbf{w})=\frac{1}{2}(\mathbf{w}^\top\mathbf{x}^{(i)}-y^{(i)})^2$.
#
# Gradient descent requires to go through all training examples to compute a single gradient, which may be time consuming if the sample size is large. Minibatch gradient descent improves the efficiency by using a subset of training examples to build an **approximate** gradient. At each iteration, it first randomly draws a set $B_t\subseteq\{1,2,\ldots,n\}$ of size $b$, where we often call $b$ the minibatch size. Then it builds an approximate gradient by
# $$
# \nabla^{B_t}(\mathbf{w}^{(t)})=\frac{1}{b}\sum_{i\in B_t}\nabla C_i(\mathbf{w}^{(t)})
# $$
# Now, it updates the model by
# $$
# \mathbf{w}^{(t+1)}=\mathbf{w}^{(t)}-\eta_t\nabla^{B_t}(\mathbf{w}^{(t)}).
# $$
# It is recommended to use $b\in[20,100]$. Depending on different $b$, minibatch gradient descent recovers several algorithms
# \begin{align*}
#   b<n \Rightarrow \text{Minibatch gradient descent}\\
#   b=1 \Rightarrow \text{Stochastic gradient descent}
# \end{align*}
# In the following, we request you to finish the following implementation of the `minibatch gradient descent` on the linear regression problem. To search a subset of $\{1,2,\ldots,n\}$, we recommend you to use the function `random.sample`. The syntax is `random.sample(sequence, k)`, which returns $k$ length new list of elements chosen from the `sequence`. More details can be found  [here](https://www.geeksforgeeks.org/python-random-sample-function/)

# %%
def solve_via_minibatch(X, y, print_every=100,
                               niter=5000, eta=1, batch_size=50):
    '''
    Solves for linear regression weights with nesterov momentum.
    Given `X` - matrix of shape (N,D) of input features
          `y` - target y values
          `print_every` - we report performance every 'print_every' iterations
          `niter` - the number of iterates allowed
          `eta` - learning rate
          `batch_size` - the size of minibatch
    Return
        `w` - weights after `niter` iterations
        `idx_res` - the indices of iterations where we compute the cost
        `err_res` - the cost at iterations
    '''
    N, D = np.shape(X)
    # initialize all the weights to zeros
    w = np.zeros([D])
    idx_res = []
    err_res = []
    tset = list(range(N))
    for k in range(niter):
        # TODO: Insert your code to update w by minibatch gradient descent
        idx = random.sample(tset, batch_size)
        #sample batch of data
        sample_X = X[idx, :]
        sample_y = y[idx]
        w = w - eta * gradfn(w, sample_X, sample_y)

        if k % print_every == print_every - 1:
            t_cost = cost(w, X, y)
            print('error after %d iteration: %s' % (k, t_cost))
            idx_res.append(k)
            err_res.append(t_cost)
    return w, idx_res, err_res

# %% [markdown]
# Now we apply minibatch gradient descent to solve the Boston House Price prediction problem.

# %%
w_batch, idx_batch, err_batch = solve_via_minibatch(X=x_in, y=y_target)
# Out:
# error after 99 iteration: 31.973608395140072
# error after 199 iteration: 31.598458465869303
# error after 299 iteration: 31.138044812199098
# error after 399 iteration: 33.05197688635532
# error after 499 iteration: 29.906396761594312
# error after 599 iteration: 29.51536003744416
# error after 699 iteration: 29.795286965179283
# error after 799 iteration: 29.3966305823159
# error after 899 iteration: 29.32067567776328
# error after 999 iteration: 31.52893422070146
# error after 1099 iteration: 28.602932478912834
# error after 1199 iteration: 28.23388453593797
# error after 1299 iteration: 29.577280043939545
# error after 1399 iteration: 28.453177085157808
# error after 1499 iteration: 28.610862288010956
# error after 1599 iteration: 27.791143679843255
# error after 1699 iteration: 29.015419013400678
# error after 1799 iteration: 29.721920581417972
# error after 1899 iteration: 27.26472192655737
# error after 1999 iteration: 27.905999893244026
# error after 2099 iteration: 26.930494735700048
# error after 2199 iteration: 26.973265040572077
# error after 2299 iteration: 26.55190756757109
# error after 2399 iteration: 26.62756566394775
# error after 2499 iteration: 26.380046286089478
# error after 2599 iteration: 27.047910727859843
# error after 2699 iteration: 27.619218064256323
# error after 2799 iteration: 25.867667723244278
# error after 2899 iteration: 25.689262357376276
# error after 2999 iteration: 25.571127655935552
# error after 3099 iteration: 25.480010728022858
# error after 3199 iteration: 25.39869010154725
# error after 3299 iteration: 25.497086719494018
# error after 3399 iteration: 25.33404750911279
# error after 3499 iteration: 24.990283542404118
# error after 3599 iteration: 25.185463935252088
# error after 3699 iteration: 25.1719803708513
# error after 3799 iteration: 24.705017461942866
# error after 3899 iteration: 24.68772553776288
# error after 3999 iteration: 24.785083047536524
# error after 4099 iteration: 24.808002955789036
# error after 4199 iteration: 27.368371522756952
# error after 4299 iteration: 24.173051880133738
# error after 4399 iteration: 24.35393630767585
# error after 4499 iteration: 25.279026867241082
# error after 4599 iteration: 23.862425144746506
# error after 4699 iteration: 24.24453371718734
# error after 4799 iteration: 24.09119497101607
# error after 4899 iteration: 23.666122436137265
# error after 4999 iteration: 23.867365513979102

# %%
w_sgd, idx_sgd, err_sgd = solve_via_minibatch(X=x_in, y=y_target, batch_size = 10)
# Out:
# error after 99 iteration: 33.27247600185053
# error after 199 iteration: 31.214582602655497
# error after 299 iteration: 38.73336920906226
# error after 399 iteration: 44.1889960934991
# error after 499 iteration: 35.037087533525145
# error after 599 iteration: 30.272320809232525
# error after 699 iteration: 30.51103043986502
# error after 799 iteration: 29.36135202326069
# error after 899 iteration: 29.20404527110232
# error after 999 iteration: 28.82156175822827
# error after 1099 iteration: 28.87134303067954
# error after 1199 iteration: 33.39390714012802
# error after 1299 iteration: 38.50969252701165
# error after 1399 iteration: 28.199397631575263
# error after 1499 iteration: 27.818420116779365
# error after 1599 iteration: 30.745013631193533
# error after 1699 iteration: 30.193142197520825
# error after 1799 iteration: 27.670140978216335
# error after 1899 iteration: 27.98715380528683
# error after 1999 iteration: 27.10643470402249
# error after 2099 iteration: 34.54195401838807
# error after 2199 iteration: 28.98305856409979
# error after 2299 iteration: 27.034753314048256
# error after 2399 iteration: 27.745460822494238
# error after 2499 iteration: 44.894368158532004
# error after 2599 iteration: 26.474805035923932
# error after 2699 iteration: 29.25908182199613
# error after 2799 iteration: 25.981640377432253
# error after 2899 iteration: 27.74594205791773
# error after 2999 iteration: 28.681274966828752
# error after 3099 iteration: 36.55928120668933
# error after 3199 iteration: 25.6040198750722
# error after 3299 iteration: 26.74815392162139
# error after 3399 iteration: 29.26109039994302
# error after 3499 iteration: 29.495825223035386
# error after 3599 iteration: 27.156452103660033
# error after 3699 iteration: 28.634055789170006
# error after 3799 iteration: 30.01362246458628
# error after 3899 iteration: 27.75115081510182
# error after 3999 iteration: 27.744103855648213
# error after 4099 iteration: 24.80866555943481
# error after 4199 iteration: 24.753166618130496
# error after 4299 iteration: 28.981506408084766
# error after 4399 iteration: 24.385573243435292
# error after 4499 iteration: 25.137086788920584
# error after 4599 iteration: 27.657041230145747
# error after 4699 iteration: 24.947995734827426
# error after 4799 iteration: 25.647066845087895
# error after 4899 iteration: 25.914401275964668
# error after 4999 iteration: 23.624548277566003

# %% [markdown]
# ### Comparison between Minibatch Gradient Descent and Gradient Descent
#
# We can now compare the behavie of Minibatch Gradient Descent and Gradient Descent. In particular, we will show how the `cost` of models found by the algorithm at different iterations would behave with respect to the iteration number.

# %%
plt.plot(idx_batch, err_batch, color="red", linewidth=2.5, linestyle="-", label="minibatch")
plt.plot(idx_gd, err_gd, color="blue", linewidth=2.5, linestyle="-", label="gradient descent")
plt.plot(idx_sgd, err_sgd, color="green", linewidth=2.5, linestyle="-", label="stochastic gradient descent" )
plt.legend(loc='upper right', prop={'size': 12})
plt.title('comparison between minibatch gradient descent and gradient descent')
plt.xlabel("number of iterations")
plt.ylabel("cost")
plt.grid()
plt.show()
